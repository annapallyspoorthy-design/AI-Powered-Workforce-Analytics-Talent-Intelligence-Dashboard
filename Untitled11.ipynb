# %% [markdown]
# <a href="https://colab.research.google.com/github/annapallyspoorthy-design/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = [1, 2, 3, 4, 5]
my_tuple = (6, 7, 8, 9, 10)

print("List:", my_list)
print("Tuple:", my_tuple)
# Out:
# List: [1, 2, 3, 4, 5]
# Tuple: (6, 7, 8, 9, 10)
